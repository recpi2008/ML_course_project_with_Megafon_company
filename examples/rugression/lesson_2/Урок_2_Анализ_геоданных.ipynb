# %%
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 10, 8
# %matplotlib inline

# %% [markdown]
# Ноутбук посвящен работе с геоданными с помощью библиотек shapely и geopandas.

# %% [markdown]
# ### Знакомство с shapely

# %% [markdown]
# `Shapely` - библиотека для работы с геометрическими объектами
#
# `Geopandas` - pandas, только с гео
#
# `folium` - для визуализации

# %%
from shapely.geometry import Point, LineString, Polygon

# %% [markdown]
# #### точка

# %%
moscow_lon = 37.618423
moscow_lat = 55.751244
point = Point(moscow_lon, moscow_lat)

# %%
point

# %%
print("area ", point.area)
print("length ", point.length)
# Out:
# area  0.0
# length  0.0

# %%
point.bounds
# Out:
# (37.618423, 55.751244, 37.618423, 55.751244)

# %% [markdown]
# #### Линия

# %%
moscow_lon = 37.618423
moscow_lat = 55.751244

piter_lon = 30.26417
piter_lat = 59.89444

line = LineString([(moscow_lon, moscow_lat), (piter_lon, piter_lat)])

# %%
line

# %% [markdown]
# bounds - (minx, miny, maxx, maxy)

# %%
line.bounds
# Out:
# (30.26417, 55.751244, 37.618423, 59.89444)

# %%
list(line.coords)
# Out:
# [(37.618423, 55.751244), (30.26417, 59.89444)]

# %% [markdown]
# #### Полигон

# %% [markdown]
# https://boundingbox.klokantech.com/ - сайт для создания bounding box города

# %%
polygon = Polygon([(37.3193289,55.489927), 
                   (37.9456611,55.489927),
                   (37.9456611,56.009657),
                   (37.3193289,56.009657)])
print(polygon.area)
print(polygon.length)
# Out:
# 0.32552363430599734
# 2.2921243999999916

# %%
polygon

# %% [markdown]
# Границы полигона

# %%
polygon.bounds
# Out:
# (37.3193289, 55.489927, 37.9456611, 56.009657)

# %% [markdown]
# Для полигона, у которого внутри дырка, можно найти внутренние и внешние границы

# %%
list(polygon.exterior.coords)
# Out:
# [(37.3193289, 55.489927),
#  (37.9456611, 55.489927),
#  (37.9456611, 56.009657),
#  (37.3193289, 56.009657),
#  (37.3193289, 55.489927)]

# %%
list(polygon.interiors)
# Out:
# []

# %% [markdown]
# ### Операции с геометрией

# %% [markdown]
# <img src=http://docs.qgis.org/testing/en/_images/overlay_operations.png>

# %% [markdown]
# intersection

# %%
a = Point(0, 0).buffer(1.1)
b = Point(1, 1).buffer(0.7)

# %%
b

# %%
a.intersection(b)

# %% [markdown]
# union

# %%
a.union(b)

# %%
a.difference(b)

# %% [markdown]
# contains

# %%
polygon.contains(Point(moscow_lon, moscow_lat))
# Out:
# True

# %%
polygon.contains(Point(piter_lon, piter_lat))
# Out:
# False

# %% [markdown]
# ### Geopandas

# %%
geo_series = gpd.GeoSeries([Point(-120, 45), Point(-121.2, 46), Point(-122.9, 47.5)])
geo_series
# Out:
# 0    POINT (-120.00000 45.00000)
# 1    POINT (-121.20000 46.00000)
# 2    POINT (-122.90000 47.50000)
# dtype: geometry

# %%
geo_series.crs = {'init': 'epsg:4326'}
# Out:
# /home/recpi/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# #### GeoDataFrame

# %%
moscow_districts = gpd.read_file('moscow_districts.geojson')

# %%
moscow_districts.columns = moscow_districts.columns.str.lower()

# %%
moscow_districts.head()
# Out:
#   abbrev_ao  men18_27  men18_60  menolder60            name  retirement  \
# 0       ЗАО    2550.0   15063.0      6621.0  Филёвский Парк     24272.0
# 1     ЗелАО    2277.0   11418.0      4116.0       Матушкино     15058.0
# 2       ЗАО    1054.0    5767.0      1614.0         Внуково      6399.0
# 3     ЗелАО    1628.0    8830.0      3540.0         Савёлки     12807.0
# 4     ЗелАО    1822.0   11186.0      4712.0          Силино     15518.0
#
#    totalmen  totalpopul  totalwomen  under18  women18_55  womenolder  \
# 0   26066.0     62378.0     36312.0   8474.0     14569.0     17651.0
# 1   19196.0     44258.0     25062.0   6834.0     10948.0     10942.0
# 2    9174.0     21378.0     12204.0   3436.0      5775.0      4785.0
# 3   15214.0     35510.0     20296.0   5494.0      8379.0      9267.0
# 4   19343.0     43495.0     24152.0   6587.0     10204.0     10806.0
#
#    working_ag                                           geometry
# 0     29632.0  POLYGON ((37.42765 55.74821, 37.42849 55.74875...
# 1     22366.0  POLYGON ((37.17853 56.00795, 37.18083 56.00825...
# 2     11542.0  MULTIPOLYGON (((37.18317 55.60565, 37.18455 55...
# 3     17209.0  POLYGON ((37.20946 56.00083, 37.20975 56.00088...
# 4     21390.0  POLYGON ((37.13160 56.01645, 37.13266 56.01678...

# %%
moscow_districts.plot('totalpopul', figsize=(12,10), cmap='OrRd');

# %% [markdown]
# #### OpenStreetMap

# %% [markdown]
# Скачаем данные по местам из OpenStreetMap на примере Москвы

# %% [markdown]
# https://wiki.openstreetmap.org/wiki/Main_Page

# %% [markdown]
# `node` - точка, параметры широта и долгота
#
# `way` - линейные объекты, например улица, дорога
#
# `relation` - отношение, для связи между объектами

# %%
import requests

# %% [markdown]
# https://wiki.openstreetmap.org/wiki/Map_Features - информация по категориям

# %%
overpass_url = "https://overpass.kumi.systems/api/interpreter"

overpass_query = """
[out:json];
(
 node["shop"](55.4245,37.0919,56.0671,38.1335);
);
out body;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.57.1 74a55df1',
#  'osm3s': {'timestamp_osm_base': '2022-04-26T07:24:10Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 1000,
#    'lat': 55.9951147,
#    'lon': 37.2075319,
#    'tags': {'comment': 'ООО "АСП-ГРУПП", ИНН 7735108290, до 22:45 c 2014-05-23',
#     'name': 'Десяточка',
#     'opening_hours': '08:30-22:45',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 245868628,
#    'lat': 55.9131682,
#    'lon': 37.3961899,
#    'tags': {'addr:city': 'Химки',
#     'addr:housenumber': 'к4',
#     'addr:postcode': '141410',
#     'addr:street': 'микрорайон ИКЕА',
#     'brand': 'Ашан',
#     'brand:en': 'Auchan',
#     'brand:ru': 'Ашан',
#     'brand:wikidata': 'Q758603',
#     'brand:wikipedia': 'ru:Auchan',
#     'contact:facebook': 'https://www.facebook.com/AuchanRussia',
#     'contact:instagram': 'https://www.instagram.com/auchan.ru/',
#     'contact:phone': '+7 800 7005800',
#     'contact:twitter': 'https://twitter.com/Auchan_ru',
#     'contact:vk': 'https://vk.com/auchan',
#     'contact:website': 'https://www.auchan.ru',
#     'contact:youtube': 'https://www.youtube.com/channel/UCoPpvvMHzIpZ7EcNZBEWhFg',
#     'level': '0',
#     'name': 'Ашан',
#     'name:en': 'Auchan',
#     'name:ru': 'Ашан',
#     'opening_hours': '08:00-24:00',
#     'opening_hours:url': 'https://www.auchan.ru/shops/',
#     'operator': 'ООО "АШАН"',
#     'ref': 'Химки',
#     'shop': 'supermarket',
#     'supermarket': 'hypermarket'}},
#   {'type': 'node',
#    'id': 245869056,
#    'lat': 55.912037,
#    'lon': 37.3929142,
#    'tags': {'addr:city': 'Химки',
#     'addr:housenumber': 'к3',
#     'addr:postcode': '141410',
#     'addr:street': 'микрорайон ИКЕА',
#     'contact:email': 'info@obi.ru',
#     'contact:phone': '+7 495 7777575;+7 495 9808818',
#     'contact:website': 'https://www.obi.ru/',
#     'name': 'Оби',
#     'name:de': 'Obi',
#     'name:en': 'Obi',
#     'name:ru': 'Оби',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'operator': 'OBI',
#     'shop': 'doityourself'}},
#   {'type': 'node',
#    'id': 245942565,
#    'lat': 55.6560537,
#    'lon': 38.0688893,
#    'tags': {'amenity': 'fuel',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'Олимп+',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 249300822,
#    'lat': 55.6346684,
#    'lon': 37.7704332,
#    'tags': {'addr:housenumber': '20 к1',
#     'addr:street': 'Братеевская улица',
#     'amenity': 'fuel',
#     'brand': 'Лукойл',
#     'car_wash': 'yes',
#     'contact:website': 'http://www.lukoil.ru',
#     'fuel:diesel': 'yes',
#     'fuel:lpg': 'no',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'no',
#     'name': 'Лукойл',
#     'opening_hours': '24/7',
#     'operator': 'ООО "ЛУКОЙЛ-Центрнефтепродукт"',
#     'payment:cards': 'yes',
#     'ref': '552',
#     'shop': 'yes',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 262615748,
#    'lat': 55.7952521,
#    'lon': 37.978164,
#    'tags': {'addr:housenumber': '17',
#     'addr:street': 'улица Фадеева',
#     'brand': 'Дикси',
#     'brand:en': 'Dixy',
#     'brand:wikidata': 'Q4161561',
#     'brand:wikipedia': 'ru:Дикси (сеть магазинов)',
#     'contact:website': 'http://dixy.ru',
#     'name': 'Дикси',
#     'opening_hours': '10:00-22:00',
#     'operator': 'ОАО "Дикси Групп"',
#     'payment:cards': 'yes',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 262615793,
#    'lat': 55.7977446,
#    'lon': 37.9837745,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'shop': 'supermarket',
#     'website': 'http://e5.ru/'}},
#   {'type': 'node',
#    'id': 262642889,
#    'lat': 55.7489449,
#    'lon': 38.0259597,
#    'tags': {'brand': 'Дикси',
#     'contact:website': 'http://dixy.ru',
#     'name': 'Дикси',
#     'opening_hours': '09:00-22:00',
#     'operator': 'ОАО "Дикси Групп"',
#     'payment:cards': 'yes',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 262894717,
#    'lat': 55.7959223,
#    'lon': 37.9632737,
#    'tags': {'name': 'Галион', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 264532445,
#    'lat': 55.7649868,
#    'lon': 37.3648009,
#    'tags': {'amenity': 'fuel',
#     'atm': 'yes',
#     'brand': 'Лукойл',
#     'car_wash': 'yes',
#     'contact:website': 'http://www.lukoil.ru',
#     'fuel:diesel': 'yes',
#     'fuel:discount': 'licard',
#     'fuel:lpg': 'no',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'yes',
#     'name': 'Лукойл',
#     'opening_hours': '24/7',
#     'operator': 'ООО "ЛУКОЙЛ-Центрнефтепродукт"',
#     'payment:cards': 'yes',
#     'ref': '475',
#     'shop': 'yes',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 266842012,
#    'lat': 55.8608085,
#    'lon': 37.5033458,
#    'tags': {'addr:city': 'Москва',
#     'addr:housenumber': '28 с1',
#     'addr:postcode': '125413',
#     'addr:street': 'Фестивальная улица',
#     'brand': 'ВкусВилл',
#     'contact:email': 'info@izbenka.msk.ru',
#     'contact:facebook': 'https://www.facebook.com/vkusvill.ru',
#     'contact:instagram': 'https://www.instagram.com/vkusvill_ru/',
#     'contact:phone': '+7 495 6638602',
#     'contact:telegram': 'https://telegram.me/vkusvillbot',
#     'contact:twitter': 'https://twitter.com/we_are_vkusvill',
#     'contact:vk': 'https://vk.com/vkusvill_ru',
#     'contact:website': 'https://vkusvill.ru',
#     'description': 'Магазины "Избёнка" и "ВкусВилл" - это крупная торговая сеть по продаже натуральных продуктов для здорового питания. Наши магазины работают для тех, кто знает толк в качественных продуктах и верит, что в России можно вести честный бизнес.',
#     'email': 'info@izbenka.msk.ru',
#     'name': 'ВкусВилл',
#     'name:ru': 'ВкусВилл',
#     'opening_hours': 'Mo-Su 09:00-22:00',
#     'operator': 'ВкусВилл',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:maestro': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'payment:visa_electron': 'yes',
#     'phone': '+7 800 5508602',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 266862392,
#    'lat': 55.8114853,
#    'lon': 37.8373363,
#    'tags': {'addr:city': 'Москва',
#     'addr:housenumber': '6',
#     'addr:postcode': '105523',
#     'addr:street': 'МКАД, 104-й километр',
#     'alt_name': 'МЕТРО Кэш энд Керри',
#     'contact:email': 'entry.store18@metro-cc.ru',
#     'contact:phone': '+7 495 5021008',
#     'contact:website': 'https://msk.metro-cc.ru/',
#     'name': 'Metro',
#     'name:en': 'METRO Cash & Carry',
#     'opening_hours': 'Mo-Su 05:00-24:00',
#     'operator': 'METRO Group',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 266950405,
#    'lat': 55.7518143,
#    'lon': 37.949588,
#    'tags': {'amenity': 'fuel',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'Лукойл',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 267581533,
#    'lat': 55.6802986,
#    'lon': 37.8488927,
#    'tags': {'amenity': 'fuel',
#     'brand': 'BP',
#     'brand:wikidata': 'Q152057',
#     'brand:wikipedia': 'en:BP',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'yes',
#     'name': 'BP',
#     'operator': 'BP',
#     'self_service': 'no',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 267677934,
#    'lat': 55.6543669,
#    'lon': 37.9921904,
#    'tags': {'opening_hours': '24/7', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 267936986,
#    'lat': 55.6448442,
#    'lon': 38.0054219,
#    'tags': {'shop': 'books'}},
#   {'type': 'node',
#    'id': 267945854,
#    'lat': 55.6444571,
#    'lon': 38.0101572,
#    'tags': {'name': 'Велотовары', 'shop': 'bicycle'}},
#   {'type': 'node',
#    'id': 271144383,
#    'lat': 55.6108204,
#    'lon': 38.0450712,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 272622083,
#    'lat': 55.6433665,
#    'lon': 37.5925369,
#    'tags': {'amenity': 'fuel',
#     'brand': 'ЕКА',
#     'contact:phone': '+7 495 5808383',
#     'contact:website': 'https://www.eka.ru',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'ЕКА',
#     'name:ru': 'ЕКА',
#     'opening_hours': '24/7',
#     'operator': 'ООО "Топливная компания ЕКА"',
#     'ref': '118',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 297517845,
#    'lat': 55.6731428,
#    'lon': 37.7504552,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 07:00-23:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 300117832,
#    'lat': 55.6328028,
#    'lon': 37.7016896,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Газпром нефть',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'yes',
#     'name': 'Газпромнефть',
#     'opening_hours': '24/7',
#     'operator': 'ОАО "Газпромнефть-Центр"',
#     'payment:cards': 'yes',
#     'ref': '93',
#     'shop': 'yes',
#     'website': 'https://www.gazprom-neft.ru/'}},
#   {'type': 'node',
#    'id': 300117839,
#    'lat': 55.6336691,
#    'lon': 37.7025312,
#    'tags': {'amenity': 'fuel',
#     'brand': 'ЕКА',
#     'cafe': 'yes',
#     'car_wash': 'yes',
#     'contact:phone': '+7 495 5808383',
#     'contact:website': 'https://www.eka.ru',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'ЕКА',
#     'name:ru': 'ЕКА',
#     'opening_hours': '24/7',
#     'operator': 'ООО "Топливная компания ЕКА"',
#     'ref': '9',
#     'shop': 'yes',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 300937447,
#    'lat': 55.9445984,
#    'lon': 37.4972268,
#    'tags': {'name': 'Маяк', 'shop': 'vacant'}},
#   {'type': 'node',
#    'id': 301100500,
#    'lat': 55.6462913,
#    'lon': 38.0397938,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 302789763,
#    'lat': 55.650389,
#    'lon': 37.982711,
#    'tags': {'contact:email': 'klient@sudar.su',
#     'contact:facebook': 'https://www.facebook.com/shopsudar/',
#     'contact:instagram': 'https://www.instagram.com/sudar_moscow/',
#     'contact:phone': '+7 495 7070000;+7 495 5014168',
#     'contact:vk': 'https://vk.com/sudarsu',
#     'contact:website': 'https://sudar.su/',
#     'name': 'Сударь',
#     'opening_hours': '09:00-21:00',
#     'operator': 'Новочеркасский',
#     'shop': 'clothes'}},
#   {'type': 'node',
#    'id': 302794212,
#    'lat': 55.6447411,
#    'lon': 37.9810856,
#    'tags': {'name': 'Продукты', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 302805768,
#    'lat': 55.6608013,
#    'lon': 37.9734623,
#    'tags': {'opening_hours': '24/7', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 302807887,
#    'lat': 55.6616782,
#    'lon': 37.9736234,
#    'tags': {'shop': 'doityourself'}},
#   {'type': 'node',
#    'id': 302808559,
#    'lat': 55.6601296,
#    'lon': 37.9771376,
#    'tags': {'name': 'Магнит у дома', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 302808806,
#    'lat': 55.6598275,
#    'lon': 37.9900223,
#    'tags': {'name': 'Супермаркет ТДК', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 303186309,
#    'lat': 55.7042822,
#    'lon': 37.4589803,
#    'tags': {'amenity': 'fuel',
#     'fuel:diesel': 'yes',
#     'fuel:octane_91': 'no',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'yes',
#     'name': 'Роснефть АЗК №9',
#     'opening_hours': '24/7',
#     'operator': 'ОАО РН-МОСКВА',
#     'ref': '9',
#     'shop': 'yes',
#     'website': 'https://www.rosneft.ru/'}},
#   {'type': 'node',
#    'id': 303546176,
#    'lat': 55.8456788,
#    'lon': 37.3801623,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Лукойл',
#     'contact:website': 'http://www.lukoil.ru',
#     'fuel:diesel': 'yes',
#     'fuel:lpg': 'no',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'no',
#     'name': 'Лукойл',
#     'opening_hours': '24/7',
#     'operator': 'ООО "ЛУКОЙЛ-Центрнефтепродукт"',
#     'payment:cards': 'yes',
#     'ref': '510',
#     'shop': 'yes',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 304480046,
#    'lat': 55.6620656,
#    'lon': 38.0126954,
#    'tags': {'name': 'Мебелия', 'shop': 'furniture'}},
#   {'type': 'node',
#    'id': 304480051,
#    'lat': 55.6617633,
#    'lon': 38.0122142,
#    'tags': {'name': 'Автозапчасти', 'shop': 'car_parts'}},
#   {'type': 'node',
#    'id': 305620739,
#    'lat': 55.7218747,
#    'lon': 37.6987539,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Лукойл',
#     'contact:website': 'http://www.lukoil.ru',
#     'fuel:diesel': 'yes',
#     'fuel:lpg': 'no',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'yes',
#     'name': 'Лукойл',
#     'opening_hours': '24/7',
#     'operator': 'ООО "ЛУКОЙЛ-Центрнефтепродукт"',
#     'payment:cards': 'yes',
#     'ref': '523',
#     'shop': 'yes',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 306123480,
#    'lat': 55.6550255,
#    'lon': 37.9840623,
#    'tags': {'name': 'молочные продукты домашние', 'shop': 'dairy'}},
#   {'type': 'node',
#    'id': 308215735,
#    'lat': 55.6340948,
#    'lon': 38.0444249,
#    'tags': {'brand': 'Дикси',
#     'brand:wikidata': 'Q4161561',
#     'brand:wikipedia': 'ru:Дикси (сеть магазинов)',
#     'contact:phone': '+7 800 3330201',
#     'contact:vk': 'https://vk.com/dixyclub',
#     'contact:website': 'https://dixy.ru',
#     'contact:youtube': 'https://www.youtube.com/channel/UCfFxD9xhL67LxHvsDOp_rvg',
#     'level': '1',
#     'name': 'Дикси',
#     'name:ru': 'Дикси',
#     'opening_hours': '09:00-22:00',
#     'operator': 'ОАО "Дикси Групп"',
#     'payment:cards': 'yes',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 308216769,
#    'lat': 55.6345806,
#    'lon': 38.0435258,
#    'tags': {'shop': 'books'}},
#   {'type': 'node',
#    'id': 308228564,
#    'lat': 55.7163931,
#    'lon': 37.4584862,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'check_date:opening_hours': '2022-03-25',
#     'contact:email': 'vopros@5ka.ru',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:instagram': 'https://www.instagram.com/pyaterochka_official',
#     'contact:ok': 'https://ok.ru/pyaterochka',
#     'contact:phone': '+7 800 5555505',
#     'contact:vk': 'https://vk.com/pyaterochka_shop',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 308228585,
#    'lat': 55.7190211,
#    'lon': 37.4613559,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'check_date:opening_hours': '2021-09-03',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 09:00-23:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 308230918,
#    'lat': 55.7141285,
#    'lon': 37.4537776,
#    'tags': {'contact:email': 'samsonov@aroma.ru',
#     'contact:phone': '+7 495 7775190',
#     'contact:website': 'https://amwine.ru',
#     'name': 'Ароматный мир',
#     'name:ru': 'Ароматный мир',
#     'opening_hours': 'Mo-Sa 09:30-22:30;Su 10:00-22:00',
#     'operator': 'ООО "Арома Маркет"',
#     'shop': 'alcohol'}},
#   {'type': 'node',
#    'id': 308231571,
#    'lat': 55.7270007,
#    'lon': 37.471613,
#    'tags': {'brand': 'Спортмастер',
#     'brand:en': 'Sportmaster',
#     'brand:ru': 'Спортмастер',
#     'brand:wikidata': 'Q4438176',
#     'brand:wikipedia': 'ru:Спортмастер',
#     'email': 'e-commerce@sportmaster.ru',
#     'name': 'Спортмастер',
#     'name:en': 'Sportmaster',
#     'name:ru': 'Спортмастер',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'operator': 'ООО «Спортмастер»',
#     'phone': '+7 495 7777771;+7 499 4452100;+7 906 0383188;+7 906 0382120',
#     'shop': 'sports',
#     'website': 'https://www.sportmaster.ru/store/143/'}},
#   {'type': 'node',
#    'id': 308232683,
#    'lat': 55.7263419,
#    'lon': 37.4671607,
#    'tags': {'alt_name': 'Перекрёсток',
#     'brand': 'Перекресток',
#     'contact:facebook': 'https://www.facebook.com/perekrestok',
#     'contact:instagram': 'http://instagram.com/perekrestok',
#     'contact:ok': 'https://ok.ru/perekrestok.shop',
#     'contact:phone': '+7 495 4453790;+7 499 5538119',
#     'contact:twitter': 'https://twitter.com/perekrestok',
#     'contact:vk': 'https://vk.com/perekrestok_shop',
#     'contact:website': 'https://www.perekrestok.ru',
#     'name': 'Перекресток',
#     'name:en': 'Perekryostok',
#     'name:ru': 'Перекресток',
#     'opening_hours': '24/7',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'operator:wikidata': 'Q1684639',
#     'operator:wikipedia': 'ru:Перекрёсток (сеть магазинов)',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 308232946,
#    'lat': 55.7190415,
#    'lon': 37.460131,
#    'tags': {'name': 'Марина-ЕА',
#     'opening_hours': 'Mo-Fr 09:00-21:00; Sa 09:00-19:00; Su 10:00-19:00',
#     'phone': '+7 495 4455864',
#     'shop': 'hairdresser'}},
#   {'type': 'node',
#    'id': 308233515,
#    'lat': 55.7269568,
#    'lon': 37.4706019,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 310109542,
#    'lat': 55.811407,
#    'lon': 37.4871017,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Лукойл',
#     'car_wash': 'yes',
#     'contact:website': 'http://www.lukoil.ru',
#     'fuel:diesel': 'yes',
#     'fuel:lpg': 'no',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'no',
#     'name': 'Лукойл',
#     'opening_hours': '24/7',
#     'operator': 'ООО "ЛУКОЙЛ-Центрнефтепродукт"',
#     'payment:cards': 'yes',
#     'ref': '525',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 310180594,
#    'lat': 55.6128345,
#    'lon': 37.7194123,
#    'tags': {'addr:country': 'RU',
#     'alt_name': 'Перекрёсток',
#     'brand': 'Перекрёсток',
#     'brand:en': 'Perekryostok',
#     'brand:wikidata': 'Q1684639',
#     'brand:wikipedia': 'en:Perekrestok (supermarket chain)',
#     'name': 'Перекрёсток',
#     'name:ru': 'Перекрёсток',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'phone': '+7 495 6628888',
#     'shop': 'supermarket',
#     'website': 'https://www.perekrestok.ru/'}},
#   {'type': 'node',
#    'id': 310183449,
#    'lat': 55.6127758,
#    'lon': 37.7199358,
#    'tags': {'level': '2',
#     'opening_hours': 'Mo-Su 10:00-21:30',
#     'operator': 'ozon',
#     'shop': 'outpost',
#     'website': 'https://ozon.ru/'}},
#   {'type': 'node',
#    'id': 310367492,
#    'lat': 55.6134288,
#    'lon': 37.7060098,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 310752332,
#    'lat': 55.6047673,
#    'lon': 37.7122756,
#    'tags': {'addr:country': 'RU',
#     'alt_name': 'Перекрёсток',
#     'contact:facebook': 'https://www.facebook.com/perekrestok',
#     'contact:instagram': 'http://instagram.com/perekrestok',
#     'contact:ok': 'https://ok.ru/perekrestok.shop',
#     'contact:phone': '+7 495 6628888',
#     'contact:twitter': 'https://twitter.com/perekrestok',
#     'contact:vk': 'https://vk.com/perekrestok_shop',
#     'contact:website': 'https://www.perekrestok.ru',
#     'name': 'Перекресток',
#     'opening_hours': '24/7',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 310752865,
#    'lat': 55.6046219,
#    'lon': 37.7123014,
#    'tags': {'name': 'Белград', 'shop': 'mall'}},
#   {'type': 'node',
#    'id': 312712969,
#    'lat': 55.6618002,
#    'lon': 37.9969075,
#    'tags': {'name': 'Продукты',
#     'opening_hours': 'Mo-Su 08:00-22:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 312713077,
#    'lat': 55.6619694,
#    'lon': 37.9967391,
#    'tags': {'shop': 'greengrocer'}},
#   {'type': 'node',
#    'id': 312714072,
#    'lat': 55.6632201,
#    'lon': 38.0056074,
#    'tags': {'amenity': 'fuel',
#     'brand': 'НеоТек',
#     'fuel:cng': 'no',
#     'fuel:diesel': 'yes',
#     'fuel:lpg': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'НеоТек',
#     'opening_hours': '24/7',
#     'operator': 'НеоТек',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 313053117,
#    'lat': 55.6595453,
#    'lon': 38.0256254,
#    'tags': {'name': 'Мясокомбинат', 'shop': 'butcher'}},
#   {'type': 'node',
#    'id': 313065715,
#    'lat': 55.661609,
#    'lon': 38.0152565,
#    'tags': {'amenity': 'cafe',
#     'name': 'Поль Бейкери',
#     'name:en': 'Paul Bakery',
#     'shop': 'bakery',
#     'website': 'http://www.paulbakery.ru/'}},
#   {'type': 'node',
#    'id': 313614697,
#    'lat': 55.6446336,
#    'lon': 37.996951,
#    'tags': {'name': 'Продукты', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 314734628,
#    'lat': 55.634846,
#    'lon': 38.0101966,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:email': 'vopros@5ka.ru',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:instagram': 'https://www.instagram.com/pyaterochka_official',
#     'contact:ok': 'https://ok.ru/pyaterochka',
#     'contact:phone': '+7 800 5555505',
#     'contact:vk': 'https://vk.com/club19098821',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 08:00-22:00',
#     'operator': 'X5 Retail Group',
#     'payment:cards': 'yes',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 314735865,
#    'lat': 55.6383686,
#    'lon': 38.0097648,
#    'tags': {'name': 'Продукты', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 314743664,
#    'lat': 55.6442831,
#    'lon': 38.0103439,
#    'tags': {'name': 'Книги', 'shop': 'books'}},
#   {'type': 'node',
#    'id': 314743772,
#    'lat': 55.6441718,
#    'lon': 38.0103056,
#    'tags': {'name': 'Домовёнок',
#     'operator': 'ЛРПО "Возрождение"',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 315964149,
#    'lat': 55.6597344,
#    'lon': 38.0370281,
#    'tags': {'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 316780731,
#    'lat': 55.8797095,
#    'lon': 37.5921624,
#    'tags': {'name': 'ДА!',
#     'opening_hours': '08:00-22:00',
#     'phone': '+7 495 6644042',
#     'shop': 'supermarket',
#     'website': 'https://market-da.ru/'}},
#   {'type': 'node',
#    'id': 317159079,
#    'lat': 55.8223029,
#    'lon': 37.641155,
#    'tags': {'name': 'Кассы метро',
#     'shop': 'ticket',
#     'tickets:public_transport': 'yes'}},
#   {'type': 'node',
#    'id': 317208879,
#    'lat': 55.5684017,
#    'lon': 37.5853483,
#    'tags': {'addr:country': 'RU',
#     'alt_name': 'Перекресток',
#     'brand': 'Перекрёсток',
#     'brand:en': 'Perekryostok',
#     'brand:wikidata': 'Q1684639',
#     'brand:wikipedia': 'en:Perekrestok (supermarket chain)',
#     'name': 'Перекрёсток',
#     'name:ru': 'Перекрёсток',
#     'opening_hours': '24/7',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'phone': '+7 495 6628888',
#     'shop': 'supermarket',
#     'website': 'https://www.perekrestok.ru/'}},
#   {'type': 'node',
#    'id': 317274505,
#    'lat': 55.5693626,
#    'lon': 37.5836254,
#    'tags': {'name': 'Русь Трейд',
#     'opening_hours': 'Mo-Su 09:00-21:00',
#     'shop': 'car_parts',
#     'website': 'http://www.rus-treyd.ru/'}},
#   {'type': 'node',
#    'id': 317595997,
#    'lat': 55.6593038,
#    'lon': 37.9829356,
#    'tags': {'name': 'газеты', 'shop': 'kiosk'}},
#   {'type': 'node',
#    'id': 317596213,
#    'lat': 55.6592651,
#    'lon': 37.9828926,
#    'tags': {'name': 'цветы', 'shop': 'florist'}},
#   {'type': 'node',
#    'id': 317596329,
#    'lat': 55.6591925,
#    'lon': 37.9828755,
#    'tags': {'name': 'яйца', 'shop': 'kiosk'}},
#   {'type': 'node',
#    'id': 321720413,
#    'lat': 55.8674062,
#    'lon': 37.5310388,
#    'tags': {'brand': 'ВкусВилл',
#     'contact:email': 'info@izbenka.msk.ru',
#     'contact:facebook': 'https://www.facebook.com/vkusvill.ru',
#     'contact:instagram': 'https://www.instagram.com/vkusvill_ru/',
#     'contact:phone': '+7 495 6638602',
#     'contact:telegram': 'https://telegram.me/vkusvillbot',
#     'contact:twitter': 'https://twitter.com/we_are_vkusvill',
#     'contact:vk': 'https://vk.com/vkusvill_ru',
#     'contact:website': 'https://vkusvill.ru',
#     'dispensing': 'no',
#     'name': 'ВкусВилл',
#     'name:ru': 'ВкусВилл',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 324356810,
#    'lat': 55.7158121,
#    'lon': 37.7881119,
#    'tags': {'opening_hours': 'Mo-Fr 08:00-20:00, Sa-Su 09:00-18:00',
#     'shop': 'hairdresser'}},
#   {'type': 'node',
#    'id': 330997211,
#    'lat': 55.738679,
#    'lon': 37.4886381,
#    'tags': {'name': 'Gravity',
#     'opening_hours': 'Mo-Su 11:00-20:00',
#     'phone': '+7 499 7306094',
#     'shop': 'outdoor',
#     'website': 'http://www.gravity.ru/'}},
#   {'type': 'node',
#    'id': 345380029,
#    'lat': 55.6183832,
#    'lon': 37.7120177,
#    'tags': {'addr:housenumber': '88/26 с2',
#     'addr:street': 'Каширское шоссе',
#     'name': 'Дом книги',
#     'official_name': 'Дом книги в Орехово',
#     'opening_hours': 'Mo-Fr 09:00-21:00; Sa,Su 10:00-20:00',
#     'operator': 'ГУП ОЦ "Московский Дом книги"',
#     'phone': '+7 495 7893591',
#     'shop': 'books',
#     'website': 'http://www.mdk-arbat.ru'}},
#   {'type': 'node',
#    'id': 349110357,
#    'lat': 55.6102182,
#    'lon': 37.7294002,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:email': 'vopros@5ka.ru',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:instagram': 'https://www.instagram.com/pyaterochka_official',
#     'contact:ok': 'https://ok.ru/pyaterochka',
#     'contact:phone': '+7 800 5555505',
#     'contact:vk': 'https://vk.com/club19098821',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'shop': 'supermarket',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 359974009,
#    'lat': 55.7938454,
#    'lon': 37.9430723,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'name:ru': 'Шелл',
#     'opening_hours': '24/7',
#     'operator': 'ООО "Шелл нефть"',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 360915775,
#    'lat': 55.8901404,
#    'lon': 37.6896505,
#    'tags': {'description': 'Шиномонтаж',
#     'service': 'tyres',
#     'shop': 'car_repair'}},
#   {'type': 'node',
#    'id': 364349547,
#    'lat': 55.6100941,
#    'lon': 38.0861794,
#    'tags': {'ref': '22', 'shop': 'bicycle'}},
#   {'type': 'node',
#    'id': 364354997,
#    'lat': 55.6070182,
#    'lon': 38.0955716,
#    'tags': {'clothes': 'sports',
#     'contact:email': 'e-commerce@sportmaster.ru',
#     'contact:phone': '+7 800 7777771',
#     'contact:website': 'https://www.sportmaster.ru/',
#     'name': 'Спортмастер',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'operator': 'Спортмастер',
#     'shop': 'sports'}},
#   {'type': 'node',
#    'id': 364475755,
#    'lat': 55.6066426,
#    'lon': 38.0987789,
#    'tags': {'contact:phone': '+7 498 4820940',
#     'contact:website': 'http://www.startmaster.ru',
#     'name': 'Стартмастер',
#     'opening_hours': 'Mo-Su 10:00-21:00',
#     'shop': 'computer'}},
#   {'type': 'node',
#    'id': 364910198,
#    'lat': 55.5910027,
#    'lon': 38.1284397,
#    'tags': {'contact:email': 'store@velozhuk.ru',
#     'contact:phone': '+7 498 4812465',
#     'contact:website': 'http://velozhuk.ru',
#     'level': '-1',
#     'name': 'Эдельвейс',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'service:bicycle:repair': 'yes',
#     'shop': 'bicycle'}},
#   {'type': 'node',
#    'id': 364911978,
#    'lat': 55.6108104,
#    'lon': 38.0765536,
#    'tags': {'contact:email': 'in184@tomail.ru',
#     'contact:phone': '+7 495 7814281;+7 800 2504949;+7 963 6980657',
#     'contact:website': 'https://bi-bi.ru/',
#     'name': 'Авто 49',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'operator': 'Авто 49',
#     'payment:cards': 'yes',
#     'service': 'parts',
#     'shop': 'car_parts'}},
#   {'type': 'node',
#    'id': 365634106,
#    'lat': 55.6096752,
#    'lon': 38.0936325,
#    'tags': {'shop': 'outdoor'}},
#   {'type': 'node',
#    'id': 369333292,
#    'lat': 55.6420491,
#    'lon': 37.5427985,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 09:00-23:00',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 369333293,
#    'lat': 55.6420932,
#    'lon': 37.5419517,
#    'tags': {'shop': 'beverages'}},
#   {'type': 'node',
#    'id': 369334199,
#    'lat': 55.6412276,
#    'lon': 37.5485607,
#    'tags': {'name': 'AUDI центр Беляево', 'shop': 'car'}},
#   {'type': 'node',
#    'id': 379751284,
#    'lat': 55.7542433,
#    'lon': 37.7153975,
#    'tags': {'brand': 'ВкусВилл',
#     'brand:wikidata': 'Q57271676',
#     'brand:wikipedia': 'ru:Вкусвилл',
#     'contact:email': 'info@izbenka.msk.ru',
#     'contact:facebook': 'https://www.facebook.com/vkusvill.ru',
#     'contact:instagram': 'https://www.instagram.com/vkusvill_ru/',
#     'contact:phone': '+7 495 6638602',
#     'contact:telegram': 'https://telegram.me/vkusvillbot',
#     'contact:twitter': 'https://twitter.com/we_are_vkusvill',
#     'contact:vk': 'https://vk.com/vkusvill_ru',
#     'contact:website': 'https://vkusvill.ru',
#     'name': 'ВкусВилл',
#     'name:ru': 'ВкусВилл',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 380729524,
#    'lat': 55.7543132,
#    'lon': 37.715383,
#    'tags': {'shop': 'hairdresser'}},
#   {'type': 'node',
#    'id': 380729543,
#    'lat': 55.7534401,
#    'lon': 37.7124659,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:email': 'vopros@5ka.ru',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:instagram': 'https://www.instagram.com/pyaterochka_official',
#     'contact:ok': 'https://ok.ru/pyaterochka',
#     'contact:phone': '+7 800 5555505',
#     'contact:vk': 'https://vk.com/club19098821',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 380942139,
#    'lat': 55.8167637,
#    'lon': 37.5680648,
#    'tags': {'brand': 'Мини Лента',
#     'contact:email': 'pr@lenta.com',
#     'contact:facebook': 'https://www.facebook.com/lentacom',
#     'contact:instagram': 'https://www.instagram.com/lenta_com',
#     'contact:ok': 'https://ok.ru/group/53286834208943',
#     'contact:vk': 'https://vk.com/lentacom',
#     'contact:website': 'https://www.lenta.com',
#     'name': 'Лента',
#     'name:ru': 'Лента',
#     'operator': 'ООО "Лента"',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 385948725,
#    'lat': 55.5746378,
#    'lon': 38.1138188,
#    'tags': {'amenity': 'fuel',
#     'contact:phone': '+7 495 5567247',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_98': 'yes',
#     'name': 'МТР',
#     'operator': "ЗАО 'Маттехресурс'",
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 385954560,
#    'lat': 55.7061032,
#    'lon': 37.8451443,
#    'tags': {'amenity': 'fuel',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'VK',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 388132800,
#    'lat': 55.6317084,
#    'lon': 37.2125257,
#    'tags': {'amenity': 'fuel',
#     'atm': 'yes',
#     'brand': 'Лукойл',
#     'contact:website': 'http://www.lukoil.ru',
#     'fuel:diesel': 'yes',
#     'fuel:discount': 'licard',
#     'fuel:lpg': 'no',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'fuel:octane_98': 'no',
#     'name': 'Лукойл',
#     'opening_hours': '24/7',
#     'operator': 'ООО "ЛУКОЙЛ-Центрнефтепродукт"',
#     'payment:cash': 'yes',
#     'ref': '108',
#     'shop': 'yes',
#     'toilets': 'yes',
#     'website': 'http://www.lukoil.ru/'}},
#   {'type': 'node',
#    'id': 388582193,
#    'lat': 55.6057196,
#    'lon': 37.7172733,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 388583412,
#    'lat': 55.6044356,
#    'lon': 37.7078201,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su,PH 08:00-22:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 390308857,
#    'lat': 55.8138473,
#    'lon': 37.3908742,
#    'tags': {'opening_hours': '24/7', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 390374792,
#    'lat': 55.5967796,
#    'lon': 38.1196587,
#    'tags': {'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:email': 'vopros@5ka.ru',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:instagram': 'https://www.instagram.com/pyaterochka_official',
#     'contact:ok': 'https://ok.ru/pyaterochka',
#     'contact:phone': '+7 800 5555505',
#     'contact:vk': 'https://vk.com/club19098821',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 09:00-23:00',
#     'operator': 'X5 Retail Group',
#     'payment:cards': 'yes',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 390457967,
#    'lat': 55.6019066,
#    'lon': 38.1011356,
#    'tags': {'name': 'Продукты', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 390499471,
#    'lat': 55.6049982,
#    'lon': 38.0902192,
#    'tags': {'name': 'Продукты', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 393994064,
#    'lat': 55.5642505,
#    'lon': 38.0430048,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 395493023,
#    'lat': 55.7061032,
#    'lon': 37.1604583,
#    'tags': {'addr:country': 'RU',
#     'alt_name': 'Перекрёсток',
#     'brand': 'Перекресток',
#     'brand:en': 'Perekrestok',
#     'brand:wikidata': 'Q1684639',
#     'brand:wikipedia': 'en:Perekrestok (supermarket chain)',
#     'contact:phone': '+7 800 2009555;+7 495 6628888',
#     'name': 'Перекрёсток',
#     'name:ru': 'Перекрёсток',
#     'opening_hours': '24/7',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'shop': 'supermarket',
#     'website': 'https://www.perekrestok.ru/'}},
#   {'type': 'node',
#    'id': 395527700,
#    'lat': 55.6720898,
#    'lon': 37.2690413,
#    'tags': {'contact:email': 'in104@tomail.ru',
#     'contact:phone': '+7 495 5907868;+7 800 2504949;+7 965 2096197',
#     'contact:website': 'https://bi-bi.ru/',
#     'name': 'Би-Би',
#     'old_name': 'Авто 49',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'shop': 'car_parts'}},
#   {'type': 'node',
#    'id': 416505042,
#    'lat': 55.7503287,
#    'lon': 37.7084383,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Роснефть',
#     'brand:en': 'Rosneft',
#     'brand:ru': 'Роснефть',
#     'brand:wikidata': 'Q1141123',
#     'brand:wikipedia': 'ru:Роснефть',
#     'name': 'Роснефть',
#     'name:en': 'Rosneft',
#     'name:ru': 'Роснефть',
#     'operator': 'Роснефть',
#     'shop': 'yes',
#     'website': 'https://www.rosneft.ru/'}},
#   {'type': 'node',
#    'id': 416822614,
#    'lat': 55.6803976,
#    'lon': 37.5834223,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 416822615,
#    'lat': 55.6772185,
#    'lon': 37.5772325,
#    'tags': {'name': 'БериСам',
#     'opening_hours': 'closed',
#     'operator': 'ООО "Аттан"',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 416822616,
#    'lat': 55.6774839,
#    'lon': 37.5783543,
#    'tags': {'name': 'Продукты',
#     'opening_hours': '09:00-23:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 416822625,
#    'lat': 55.6847501,
#    'lon': 37.5810568,
#    'tags': {'opening_hours': 'Mo-Fr 09:00-22:00, Sa-Su 08:00-23:00',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 417284566,
#    'lat': 55.9128847,
#    'lon': 37.8569915,
#    'tags': {'name': '999', 'shop': 'vacant'}},
#   {'type': 'node',
#    'id': 417789496,
#    'lat': 55.6468823,
#    'lon': 37.4751247,
#    'tags': {'amenity': 'car_wash', 'shop': 'car_repair'}},
#   {'type': 'node',
#    'id': 417797968,
#    'lat': 55.6674264,
#    'lon': 37.4948101,
#    'tags': {'addr:street': 'проспект Вернадского',
#     'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:email': 'vopros@5ka.ru',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:instagram': 'https://www.instagram.com/pyaterochka_official',
#     'contact:ok': 'https://ok.ru/pyaterochka',
#     'contact:phone': '+7 800 5555505',
#     'contact:vk': 'https://vk.com/pyaterochka_shop',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'PH,Mo-Su 09:30-22:00',
#     'operator': 'X5 Retail Group',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 417928564,
#    'lat': 55.664342,
#    'lon': 37.4697301,
#    'tags': {'alt_name': 'Перекрёсток',
#     'brand': 'Перекресток',
#     'brand:wikidata': 'Q1684639',
#     'brand:wikipedia': 'ru:Перекрёсток (сеть магазинов)',
#     'contact:facebook': 'https://www.facebook.com/perekrestok',
#     'contact:instagram': 'http://instagram.com/perekrestok',
#     'contact:ok': 'https://ok.ru/perekrestok.shop',
#     'contact:phone': '+7 495 4379610;+7 499 2130468',
#     'contact:twitter': 'https://twitter.com/perekrestok',
#     'contact:vk': 'https://vk.com/perekrestok_shop',
#     'contact:website': 'https://www.perekrestok.ru',
#     'contact:youtube': 'https://www.youtube.com/channel/UCY9Nwfy_8drHqif0iryQ7Vw',
#     'name': 'Перекресток',
#     'name:ru': 'Перекресток',
#     'opening_hours': '24/7',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 417928566,
#    'lat': 55.6703642,
#    'lon': 37.4772739,
#    'tags': {'addr:city': 'Москва',
#     'addr:housenumber': '2 к1Б',
#     'addr:postcode': '119602',
#     'addr:street': 'улица Академика Анохина',
#     'brand': 'Виктория',
#     'brand:wikidata': 'Q4111046',
#     'brand:wikipedia': 'ru:Виктория (сеть магазинов)',
#     'contact:facebook': 'https://www.facebook.com/SupermarketVictoria',
#     'contact:instagram': 'https://www.instagram.com/my_victoria24',
#     'contact:vk': 'https://vk.com/supermarket_victoria',
#     'contact:website': 'http://victoria-group.ru',
#     'name': 'Виктория',
#     'name:ru': 'Виктория',
#     'opening_hours': '24/7',
#     'operator': 'Квартал',
#     'phone': '+7 800 2004454',
#     'shop': 'supermarket',
#     'website': 'https://www.victoria-group.ru/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 418161856,
#    'lat': 55.6458669,
#    'lon': 37.4860931,
#    'tags': {'brand': 'Азбука Вкуса',
#     'brand:wikidata': 'Q4058209',
#     'brand:wikipedia': 'ru:Азбука вкуса',
#     'contact:email': 'welcome@azbukavkusa.ru',
#     'contact:facebook': 'https://www.facebook.com/AzbukaVkusa',
#     'contact:instagram': 'https://www.instagram.com/azbukavkusa',
#     'contact:phone': '+7 800 7003487',
#     'contact:twitter': 'https://twitter.com/azbukavkusa',
#     'contact:vk': 'https://vk.com/azbukavkusa',
#     'contact:website': 'https://av.ru',
#     'contact:youtube': 'https://www.youtube.com/user/azbukav',
#     'name': 'Азбука Вкуса',
#     'name:ru': 'Азбука Вкуса',
#     'opening_hours': '24/7',
#     'operator': 'ООО «Городской супермаркет»',
#     'ref:av': '198478',
#     'shop': 'supermarket',
#     'website': 'https://av.ru/shops/ostrovityanova_d_2_tc_azbuka_vkusa'}},
#   {'type': 'node',
#    'id': 418194901,
#    'lat': 55.8269102,
#    'lon': 37.9000965,
#    'tags': {'amenity': 'fuel',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'Shell',
#     'name:en': 'Shell',
#     'name:ru': 'Shell',
#     'opening_hours': '24/7',
#     'shop': 'yes'}},
#   {'type': 'node',
#    'id': 418661392,
#    'lat': 55.6693891,
#    'lon': 37.4918157,
#    'tags': {'shop': 'car_repair'}},
#   {'type': 'node',
#    'id': 420017013,
#    'lat': 55.9279333,
#    'lon': 37.9820999,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Газпром нефть',
#     'building': 'yes',
#     'contact:website': 'http://www.gazprom-neft.ru',
#     'fuel:diesel': 'yes',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'Газпромнефть АЗС №35',
#     'opening_hours': '24/7',
#     'operator': 'ОАО "Газпромнефть-Северо-Запад"',
#     'payment:cards': 'yes',
#     'ref': '35',
#     'shop': 'kiosk'}},
#   {'type': 'node',
#    'id': 420511881,
#    'lat': 55.5515909,
#    'lon': 37.7022769,
#    'tags': {'alt_name': 'Перекрёсток',
#     'brand': 'Перекресток',
#     'brand:wikidata': 'Q1684639',
#     'brand:wikipedia': 'ru:Перекрёсток (сеть магазинов)',
#     'contact:facebook': 'https://www.facebook.com/perekrestok',
#     'contact:instagram': 'http://instagram.com/perekrestok',
#     'contact:ok': 'https://ok.ru/perekrestok.shop',
#     'contact:phone': '+7 495 6628888',
#     'contact:twitter': 'https://twitter.com/perekrestok',
#     'contact:vk': 'https://vk.com/perekrestok_shop',
#     'contact:website': 'https://www.perekrestok.ru',
#     'contact:youtube': 'https://www.youtube.com/channel/UCY9Nwfy_8drHqif0iryQ7Vw',
#     'name': 'Перекресток',
#     'name:ru': 'Перекресток',
#     'opening_hours': '24/7',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 420586752,
#    'lat': 55.732492,
#    'lon': 37.6424003,
#    'tags': {'name': 'Трейдинвест', 'shop': 'car', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 422924066,
#    'lat': 55.551651,
#    'lon': 37.7028627,
#    'tags': {'shop': 'chemist'}},
#   {'type': 'node',
#    'id': 423816193,
#    'lat': 55.6463514,
#    'lon': 37.4777606,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': '24/7',
#     'operator': 'X5 Retail Group',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 429455538,
#    'lat': 55.6110343,
#    'lon': 37.7243807,
#    'tags': {'brand': 'М.Видео',
#     'brand:en': 'M.video',
#     'brand:wikidata': 'Q6558800',
#     'brand:wikipedia': 'ru:М.Видео',
#     'contact:email': '24@mvideo.ru',
#     'contact:facebook': 'https://www.facebook.com/mvideo.ru',
#     'contact:instagram': 'https://www.instagram.com/mvideo_ru/',
#     'contact:ok': 'https://ok.ru/mvideo',
#     'contact:phone': '+7 495 7777775',
#     'contact:twitter': 'https://twitter.com/mvideo',
#     'contact:vk': 'https://vk.com/mvideo',
#     'contact:website': 'https://mvideo.ru/',
#     'contact:youtube': 'https://youtube.com/mvideoru',
#     'name': 'М.Видео',
#     'name:en': 'M.video',
#     'name:ru': 'М.Видео',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'operator': 'МВМ',
#     'shop': 'electronics',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 429457488,
#    'lat': 55.6099466,
#    'lon': 37.7278086,
#    'tags': {'brand': 'Billa',
#     'brand:wikidata': 'Q537781',
#     'brand:wikipedia': 'ru:Billa',
#     'contact:email': 'mail@billa.ru',
#     'contact:facebook': 'https://www.facebook.com/billa.ru',
#     'contact:fax': '+7 495 785 7501',
#     'contact:instagram': 'https://www.instagram.com/billarussia',
#     'contact:ok': 'https://ok.ru/group/53124549640396',
#     'contact:vk': 'https://vk.com/billarussia',
#     'contact:website': 'http://www.billa.ru',
#     'contact:youtube': 'https://www.youtube.com/channel/UCSx84zsrpnikJX2PDnOYbMA',
#     'ele': '1',
#     'name': 'Billa',
#     'name:en': 'Billa',
#     'name:ru': 'Билла',
#     'opening_hours': 'Mo-Su 07:00-23:00',
#     'operator': 'ООО "Билла"',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 429480773,
#    'lat': 55.610282,
#    'lon': 37.7158539,
#    'tags': {'name': 'Снежная Королева', 'shop': 'clothes'}},
#   {'type': 'node',
#    'id': 429610866,
#    'lat': 55.6985386,
#    'lon': 37.7793657,
#    'tags': {'name': 'Магнит', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 429610873,
#    'lat': 55.6976881,
#    'lon': 37.7857738,
#    'tags': {'alt_name': 'Пятерочка',
#     'amenity': 'cafe',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Старый дуб',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 430941090,
#    'lat': 55.5979887,
#    'lon': 37.7258677,
#    'tags': {'shop': 'car_repair'}},
#   {'type': 'node',
#    'id': 431245870,
#    'lat': 55.6840494,
#    'lon': 37.5702169,
#    'tags': {'contact:phone': '+7 499 1250361',
#     'contact:website': 'http://www.mdk-arbat.ru',
#     'name': 'Дом книги',
#     'opening_hours': 'Mo-Fr 09:00-21:00; Sa-Su 10:00-20:00',
#     'shop': 'books'}},
#   {'type': 'node',
#    'id': 431248994,
#    'lat': 55.6921532,
#    'lon': 37.5628029,
#    'tags': {'check_date:opening_hours': '2021-04-19',
#     'name': 'Академкнига',
#     'opening_hours': 'Mo-Fr 10:00-19:00, Sa 10:00-18:00',
#     'shop': 'books',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 432507350,
#    'lat': 55.7800347,
#    'lon': 37.6018898,
#    'tags': {'addr:country': 'RU',
#     'alt_name': 'Перекрёсток',
#     'brand': 'Перекрёсток',
#     'brand:en': 'Perekryostok',
#     'brand:wikidata': 'Q1684639',
#     'brand:wikipedia': 'en:Perekrestok (supermarket chain)',
#     'contact:facebook': 'https://www.facebook.com/perekrestok',
#     'contact:instagram': 'http://instagram.com/perekrestok',
#     'contact:ok': 'https://ok.ru/perekrestok.shop',
#     'contact:phone': '+7 495 9840715',
#     'contact:twitter': 'https://twitter.com/perekrestok',
#     'contact:vk': 'https://vk.com/perekrestok_shop',
#     'contact:website': 'https://www.perekrestok.ru/',
#     'contact:youtube': 'https://www.youtube.com/channel/UCY9Nwfy_8drHqif0iryQ7Vw',
#     'level': '2',
#     'name': 'Перекрёсток',
#     'name:ru': 'Перекресток',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'operator:wikidata': 'Q1684639',
#     'operator:wikipedia': 'ru:Перекрёсток (сеть магазинов)',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 433443222,
#    'lat': 55.6766985,
#    'lon': 37.8567166,
#    'tags': {'name': 'Shell', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 436157347,
#    'lat': 55.7033313,
#    'lon': 37.5709582,
#    'tags': {'contact:phone': '+7 499 1376019',
#     'contact:website': 'http://www.mdk-arbat.ru/maps?SID=5',
#     'name': 'Дом технической книги',
#     'opening_hours': 'Mo-Fr 09:00-22:00; Sa,Su 10:00-22:00',
#     'shop': 'books',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 437217802,
#    'lat': 55.6299663,
#    'lon': 37.4743878,
#    'tags': {'name': 'ХЦ',
# ...
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 703556458,
#    'lat': 55.8882478,
#    'lon': 37.6576523,
#    'tags': {'alt_name': 'Перекрёсток',
#     'brand': 'Перекрёсток',
#     'brand:en': 'Perekryostok',
#     'brand:wikidata': 'Q1684639',
#     'brand:wikipedia': 'en:Perekrestok (supermarket chain)',
#     'contact:facebook': 'https://www.facebook.com/perekrestok',
#     'contact:instagram': 'http://instagram.com/perekrestok',
#     'contact:ok': 'https://ok.ru/perekrestok.shop',
#     'contact:phone': '+7 495 6600510;+7 495 6628888',
#     'contact:twitter': 'https://twitter.com/perekrestok',
#     'contact:vk': 'https://vk.com/perekrestok_shop',
#     'contact:website': 'https://www.perekrestok.ru',
#     'contact:youtube': 'https://www.youtube.com/channel/UCY9Nwfy_8drHqif0iryQ7Vw',
#     'name': 'Перекрёсток',
#     'name:ru': 'Перекресток',
#     'opening_hours': '24/7',
#     'operator': 'Торговый дом "ПЕРЕКРЕСТОК"',
#     'operator:wikidata': 'Q1684639',
#     'operator:wikipedia': 'ru:Перекрёсток (сеть магазинов)',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 703754970,
#    'lat': 55.5131707,
#    'lon': 37.5642567,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 703754989,
#    'lat': 55.5146042,
#    'lon': 37.5670362,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 704380284,
#    'lat': 55.7237322,
#    'lon': 37.8286777,
#    'tags': {'brand': 'Дикси',
#     'brand:wikidata': 'Q4161561',
#     'brand:wikipedia': 'ru:Дикси (сеть магазинов)',
#     'contact:phone': '+7 800 3330201',
#     'contact:website': 'http://dixy.ru',
#     'name': 'Дикси',
#     'name:en': 'Dixy',
#     'name:ru': 'Дикси',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 704380285,
#    'lat': 55.7381023,
#    'lon': 37.8303576,
#    'tags': {'name': 'Дикси', 'name:en': 'Diksi', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 704893691,
#    'lat': 55.6488781,
#    'lon': 37.5624768,
#    'tags': {'name': 'Автосалон Рено', 'shop': 'car'}},
#   {'type': 'node',
#    'id': 705085096,
#    'lat': 55.7125296,
#    'lon': 37.8164929,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 705349160,
#    'lat': 55.6721926,
#    'lon': 37.5507669,
#    'tags': {'brand': 'Магнолия',
#     'contact:website': 'http://www.mgnl.ru',
#     'name': 'Магнолия',
#     'name:en': 'Magnoliya',
#     'name:ru': 'Магнолия',
#     'opening_hours': '24/7',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 705409499,
#    'lat': 55.7827906,
#    'lon': 37.7215345,
#    'tags': {'brand': 'Детский мир',
#     'brand:en': 'Detskiy Mir',
#     'brand:wikidata': 'Q16643324',
#     'brand:wikipedia': 'ru:Детский мир (сеть магазинов)',
#     'clothes': 'children',
#     'contact:email': 'shop@detmir.ru',
#     'contact:facebook': 'https://www.facebook.com/detmir',
#     'contact:instagram': 'https://www.instagram.com/detmir_shop',
#     'contact:phone': '+7 800 2500000',
#     'contact:twitter': 'https://twitter.com/detmir_official',
#     'contact:vk': 'https://vk.com/detmir',
#     'contact:website': 'https://www.detmir.ru/',
#     'contact:youtube': 'https://www.youtube.com/detmirtv',
#     'level': '-1',
#     'name': 'Детский мир',
#     'name:en': 'Detskiy Mir',
#     'name:ru': 'Детский мир',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'operator': 'ДЕТСКИЙ мир',
#     'shop': 'baby_goods'}},
#   {'type': 'node',
#    'id': 705486273,
#    'lat': 55.7202889,
#    'lon': 37.8208208,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 705500078,
#    'lat': 55.7215196,
#    'lon': 37.8231672,
#    'tags': {'brand': 'AvtoALL',
#     'opening_hours': 'Mo-Fr 08:00-24:00; Sa 08:00-22:00',
#     'operator': 'ОО ПКФ "Реглан"',
#     'shop': 'car_parts'}},
#   {'type': 'node',
#    'id': 705574643,
#    'lat': 55.8643055,
#    'lon': 37.6623624,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 705631387,
#    'lat': 55.7576283,
#    'lon': 37.7125653,
#    'tags': {'brand': 'Подружка',
#     'contact:email': 'secretary@taber.ru',
#     'contact:facebook': 'https://www.facebook.com/podrygkashop',
#     'contact:instagram': 'https://www.instagram.com/podrygkashop',
#     'contact:phone': '+7 800 7074747',
#     'contact:vk': 'https://vk.com/podrygkashop',
#     'contact:website': 'https://www.podrygka.ru',
#     'name': 'Подружка',
#     'name:ru': 'Подружка',
#     'operator': 'ООО «ТАБЕР ТРЕЙД»',
#     'shop': 'cosmetics'}},
#   {'type': 'node',
#    'id': 706875149,
#    'lat': 55.7238069,
#    'lon': 37.8284298,
#    'tags': {'name': 'Альянс', 'shop': 'beverages', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 706875329,
#    'lat': 55.7236846,
#    'lon': 37.8210744,
#    'tags': {'name': 'Букинист', 'shop': 'books'}},
#   {'type': 'node',
#    'id': 706875395,
#    'lat': 55.7191433,
#    'lon': 37.8236237,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 07:00-23:45',
#     'shop': 'supermarket',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 707267452,
#    'lat': 55.8423537,
#    'lon': 37.4236372,
#    'tags': {'addr:city': 'Москва',
#     'addr:country': 'RU',
#     'addr:housenumber': '24',
#     'addr:street': 'Походный проезд',
#     'shop': 'car_parts'}},
#   {'type': 'node',
#    'id': 707267462,
#    'lat': 55.8444701,
#    'lon': 37.4274497,
#    'tags': {'addr:city': 'Москва',
#     'addr:country': 'RU',
#     'addr:housenumber': '48',
#     'addr:street': 'улица Фабрициуса',
#     'name': 'K-13',
#     'shop': 'car_parts'}},
#   {'type': 'node',
#    'id': 707298623,
#    'lat': 55.8422168,
#    'lon': 37.4235222,
#    'tags': {'addr:city': 'Москва',
#     'addr:country': 'RU',
#     'addr:housenumber': '24',
#     'addr:street': 'Походный проезд',
#     'name': 'Калифорния Клинерс',
#     'shop': 'laundry'}},
#   {'type': 'node',
#    'id': 708317570,
#    'lat': 55.7842372,
#    'lon': 37.7218399,
#    'tags': {'name': 'Дети', 'shop': 'toys'}},
#   {'type': 'node',
#    'id': 708425857,
#    'lat': 55.9717599,
#    'lon': 37.742586,
#    'tags': {'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 710878797,
#    'lat': 55.8877336,
#    'lon': 37.6767609,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:en': 'Pyaterochka',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:email': 'vopros@5ka.ru',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:instagram': 'https://www.instagram.com/pyaterochka_official',
#     'contact:ok': 'https://ok.ru/pyaterochka',
#     'contact:phone': '+7 800 5555505',
#     'contact:vk': 'https://vk.com/club19098821',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyaterochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 09:00-23:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 710878798,
#    'lat': 55.8875384,
#    'lon': 37.6784894,
#    'tags': {'addr:housenumber': '31/5',
#     'addr:street': 'Широкая улица',
#     'brand': 'Billa',
#     'brand:wikidata': 'Q537781',
#     'brand:wikipedia': 'en:Billa (supermarket)',
#     'contact:email': 'mail@billa.ru',
#     'contact:facebook': 'https://www.facebook.com/billa.ru',
#     'contact:fax': '+7 495 785 7501',
#     'contact:instagram': 'https://www.instagram.com/billarussia',
#     'contact:ok': 'https://ok.ru/group/53124549640396',
#     'contact:vk': 'https://vk.com/billarussia',
#     'contact:website': 'http://www.billa.ru',
#     'contact:youtube': 'https://www.youtube.com/channel/UCSx84zsrpnikJX2PDnOYbMA',
#     'name': 'Billa',
#     'name:en': 'Billa',
#     'name:ru': 'Билла',
#     'opening_hours': '08:00-24:00',
#     'operator': 'ООО "Билла"',
#     'operator:wikidata': 'Q537781',
#     'operator:wikipedia': 'ru:Billa',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 711739267,
#    'lat': 55.8182694,
#    'lon': 37.4005562,
#    'tags': {'contact:phone': '+7 495 7571169',
#     'name': 'Ваша парикмахерская',
#     'opening_hours': 'Mo-Fr 09:00-20:00',
#     'shop': 'hairdresser'}},
#   {'type': 'node',
#    'id': 711739932,
#    'lat': 55.801644,
#    'lon': 37.4061625,
#    'tags': {'contact:phone': '+7 495 7584590',
#     'name': 'Владич',
#     'opening_hours': 'Mo-Fr 09:00-21:00',
#     'payment:cash': 'yes',
#     'phone': '+7 495 7584590',
#     'shop': 'hairdresser',
#     'website': 'http://strogino.salonekonom.ru'}},
#   {'type': 'node',
#    'id': 712616948,
#    'lat': 55.8012267,
#    'lon': 37.3918378,
#    'tags': {'opening_hours': 'Mo-Su 09:00-21:00', 'shop': 'hairdresser'}},
#   {'type': 'node',
#    'id': 712663683,
#    'lat': 55.8863737,
#    'lon': 37.6572118,
#    'tags': {'name': 'Дом книги Медведково',
#     'opening_hours': '10:00-22:00',
#     'shop': 'books',
#     'website': 'www.bearbooks.ru'}},
#   {'type': 'node',
#    'id': 712663685,
#    'lat': 55.886216,
#    'lon': 37.6603506,
#    'tags': {'check_date:opening_hours': '2022-04-10',
#     'name': 'Станем друзьями',
#     'opening_hours': '09:00-22:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 712915011,
#    'lat': 55.8197696,
#    'lon': 37.8111953,
#    'tags': {'name': 'Диана',
#     'name:en': 'Diana',
#     'opening_hours': '24/7',
#     'operator': 'ООО «Диана»',
#     'shop': 'dry_cleaning',
#     'website': 'https://dryclean.ru/'}},
#   {'type': 'node',
#    'id': 712920726,
#    'lat': 55.8119603,
#    'lon': 37.7750032,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Газпром нефть',
#     'fuel:octane_92': 'yes',
#     'fuel:octane_95plus': 'yes',
#     'name': 'Газпромнефть',
#     'note': 'обычного 95 там нет, только G95 - отметил как octane_95plus за неимением лучших идей по тегированию',
#     'opening_hours': '24/7',
#     'operator': 'ОАО "Газпромнефть-Центр"',
#     'payment:cards': 'yes',
#     'payment:cash': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'ref': '2',
#     'shop': 'yes',
#     'toilets': 'yes',
#     'website': 'https://www.gazprom-neft.ru/'}},
#   {'type': 'node',
#    'id': 712934537,
#    'lat': 55.802846,
#    'lon': 37.7641737,
#    'tags': {'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 715331819,
#    'lat': 55.6555715,
#    'lon': 37.3833439,
#    'tags': {'name': 'Ремонт обуви',
#     'opening_hours': 'Mo-Fr 09:30-19:30; Sa 09:00-17:00',
#     'shop': 'shoe_repair'}},
#   {'type': 'node',
#    'id': 715343242,
#    'lat': 55.6555643,
#    'lon': 37.3828933,
#    'tags': {'name': 'Мебель',
#     'opening_hours': 'Mo-Fr 10:00-19:00; Sa 10:00-18:00; Su 10:00-17:00',
#     'shop': 'kiosk'}},
#   {'type': 'node',
#    'id': 715346137,
#    'lat': 55.6554301,
#    'lon': 37.3831447,
#    'tags': {'shop': 'hairdresser'}},
#   {'type': 'node',
#    'id': 715444993,
#    'lat': 55.90724,
#    'lon': 37.7106762,
#    'tags': {'addr:housenumber': '27',
#     'addr:street': 'Юбилейная улица',
#     'name': 'ООО «Хонка»',
#     'opening_hours': '24/7',
#     'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 715700977,
#    'lat': 55.812295,
#    'lon': 37.8281197,
#    'tags': {'addr:city': 'Москва',
#     'addr:country': 'RU',
#     'addr:housenumber': '98/57',
#     'addr:street': 'Щёлковское шоссе',
#     'contact:email': 'shop77220@koleso.ru',
#     'contact:phone': '+7 495 4688086;+7 495 5440202;+7 800 1006878',
#     'contact:vk': 'https://vk.com/kolesoru',
#     'contact:website': 'https://koleso.ru/shops/schelkovskoe-sh-d-98-57/',
#     'name': 'Колесо',
#     'opening_hours': 'Mo-Su 09:00-21:00',
#     'operator': 'САМ-МБ',
#     'service': 'tyres',
#     'shop': 'tyres'}},
#   {'type': 'node',
#    'id': 715710407,
#    'lat': 55.8121669,
#    'lon': 37.8269633,
#    'tags': {'addr:city': 'Москва',
#     'addr:country': 'RU',
#     'addr:housenumber': '96',
#     'addr:street': 'Щёлковское шоссе',
#     'alt_name': 'Пятерочка',
#     'brand': 'Пятёрочка',
#     'brand:wikidata': 'Q1768969',
#     'brand:wikipedia': 'ru:Пятёрочка',
#     'contact:facebook': 'https://www.facebook.com/pyaterochka',
#     'contact:website': 'https://5ka.ru',
#     'name': 'Пятёрочка',
#     'name:en': 'Pyatyorochka',
#     'name:ru': 'Пятёрочка',
#     'opening_hours': 'Mo-Su 07:00-23:30',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 715889445,
#    'lat': 55.8742925,
#    'lon': 37.6898825,
#    'tags': {'name': 'Изюминка', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 720810533,
#    'lat': 55.8542359,
#    'lon': 37.4503023,
#    'tags': {'addr:housenumber': '61 к2',
#     'addr:street': 'улица Свободы',
#     'name': 'Багира',
#     'shop': 'beauty'}},
#   {'type': 'node',
#    'id': 721238749,
#    'lat': 55.7193778,
#    'lon': 37.6042236,
#    'tags': {'brand': 'OLDI',
#     'inscription': 'OLDI Express',
#     'level': '-1',
#     'name': 'OLDI',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'phone': '+7 495 2211111',
#     'shop': 'computer',
#     'website': 'https://www.oldi.ru/'}},
#   {'type': 'node',
#    'id': 721238750,
#    'lat': 55.718695,
#    'lon': 37.6016163,
#    'tags': {'name': 'USN', 'shop': 'computer'}},
#   {'type': 'node',
#    'id': 724172219,
#    'lat': 55.9952982,
#    'lon': 37.2064493,
#    'tags': {'comment': 'Несколько торговых точек разной специализации в одном помещении',
#     'name': 'Альянс',
#     'opening_hours': '09:00-21:00',
#     'shop': 'convenience',
#     'source': 'photo'}},
#   {'type': 'node',
#    'id': 724214827,
#    'lat': 55.7634974,
#    'lon': 37.6228979,
#    'tags': {'alt_name': 'Fotolab',
#     'contact:phone': '+7 495 2344886;+7 495 6230724;+7 495 6231609',
#     'craft': 'photographic_laboratory',
#     'name': 'ФотоЛаб',
#     'opening_hours': 'Mo-Sa 10:00-22:00; Su 10:00-21:00',
#     'shop': 'photo',
#     'source': 'knowledge',
#     'website': 'https://www.fotolab.ru/'}},
#   {'type': 'node',
#    'id': 724223458,
#    'lat': 55.5882574,
#    'lon': 38.1330758,
#    'tags': {'level': '-1', 'shop': 'vacant'}},
#   {'type': 'node',
#    'id': 724834825,
#    'lat': 55.8223497,
#    'lon': 37.7578547,
#    'tags': {'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 724834830,
#    'lat': 55.8224203,
#    'lon': 37.7565539,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 724834831,
#    'lat': 55.8223124,
#    'lon': 37.7579347,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 725054868,
#    'lat': 55.781043,
#    'lon': 37.7181631,
#    'tags': {'addr:housenumber': '3',
#     'addr:street': 'улица Измайловский Вал',
#     'brand': 'М.Видео',
#     'brand:en': 'M.video',
#     'brand:wikidata': 'Q6558800',
#     'brand:wikipedia': 'ru:М.Видео',
#     'contact:email': '24@mvideo.ru',
#     'contact:facebook': 'https://www.facebook.com/mvideo.ru',
#     'contact:instagram': 'https://www.instagram.com/mvideo_ru/',
#     'contact:ok': 'https://ok.ru/mvideo',
#     'contact:phone': '+7 495 7777775',
#     'contact:twitter': 'https://twitter.com/mvideo',
#     'contact:vk': 'https://vk.com/mvideo',
#     'contact:website': 'https://mvideo.ru/',
#     'name': 'М.Видео',
#     'name:en': 'M.video',
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'operator': 'МВМ',
#     'operator:wikidata': 'Q6558800',
#     'operator:wikipedia': 'ru:М.Видео',
#     'ref': '14',
#     'shop': 'electronics',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 725143181,
#    'lat': 55.7412926,
#    'lon': 37.8186547,
#    'tags': {'shop': 'car_parts'}},
#   {'type': 'node',
#    'id': 726624779,
#    'lat': 55.6448792,
#    'lon': 37.5288739,
#    'tags': {'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 726624784,
#    'lat': 55.6453492,
#    'lon': 37.5301962,
#    'tags': {'shop': 'convenience'}},
#   ...]}

# %%
def get_tag(x, key_name):
    if str(key_name) in x:
        tmp = x[key_name]
        return tmp
    else:
        return "unknown"

# %%
loaded = pd.DataFrame(data['elements'])
loaded['shop'] = loaded['tags'].apply(lambda x: get_tag(x, 'shop'))

# %%
loaded.head()
# Out:
#    type         id        lat        lon  \
# 0  node       1000  55.995115  37.207532
# 1  node  245868628  55.913168  37.396190
# 2  node  245869056  55.912037  37.392914
# 3  node  245942565  55.656054  38.068889
# 4  node  249300822  55.634668  37.770433
#
#                                                 tags          shop
# 0  {'comment': 'ООО "АСП-ГРУПП", ИНН 7735108290, ...   supermarket
# 1  {'addr:city': 'Химки', 'addr:housenumber': 'к4...   supermarket
# 2  {'addr:city': 'Химки', 'addr:housenumber': 'к3...  doityourself
# 3  {'amenity': 'fuel', 'fuel:diesel': 'yes', 'fue...           yes
# 4  {'addr:housenumber': '20 к1', 'addr:street': '...           yes

# %% [markdown]
# #### Создание geodataframe

# %%
crs = {'init' :'epsg:4326'}
geometry = [Point(xy) for xy in zip(loaded.lon, loaded.lat)]
places_geo = gpd.GeoDataFrame(loaded, crs=crs, geometry=geometry)
# Out:
# /home/recpi/anaconda3/lib/python3.8/site-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
places_geo.head()
# Out:
#    type         id        lat        lon  \
# 0  node       1000  55.995115  37.207532
# 1  node  245868628  55.913168  37.396190
# 2  node  245869056  55.912037  37.392914
# 3  node  245942565  55.656054  38.068889
# 4  node  249300822  55.634668  37.770433
#
#                                                 tags          shop  \
# 0  {'comment': 'ООО "АСП-ГРУПП", ИНН 7735108290, ...   supermarket
# 1  {'addr:city': 'Химки', 'addr:housenumber': 'к4...   supermarket
# 2  {'addr:city': 'Химки', 'addr:housenumber': 'к3...  doityourself
# 3  {'amenity': 'fuel', 'fuel:diesel': 'yes', 'fue...           yes
# 4  {'addr:housenumber': '20 к1', 'addr:street': '...           yes
#
#                     geometry
# 0  POINT (37.20753 55.99511)
# 1  POINT (37.39619 55.91317)
# 2  POINT (37.39291 55.91204)
# 3  POINT (38.06889 55.65605)
# 4  POINT (37.77043 55.63467)

# %% [markdown]
# ### Spatial join

# %% [markdown]
# проверка проекций - у двух датафреймов они должны совпадать

# %%
moscow_districts.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
places_geo.crs
# Out:
# <Geographic 2D CRS: +init=epsg:4326 +type=crs>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
places_district = gpd.sjoin(moscow_districts, places_geo, how="inner", op='contains')
# Out:
# /home/recpi/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# <ipython-input-39-1cf444394c5b>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: +init=epsg:4326 +type=crs
#
#   places_district = gpd.sjoin(moscow_districts, places_geo, how="inner", op='contains')

# %%
places_district.head()
# Out:
#   abbrev_ao  men18_27  men18_60  menolder60            name  retirement  \
# 0       ЗАО    2550.0   15063.0      6621.0  Филёвский Парк     24272.0
# 0       ЗАО    2550.0   15063.0      6621.0  Филёвский Парк     24272.0
# 0       ЗАО    2550.0   15063.0      6621.0  Филёвский Парк     24272.0
# 0       ЗАО    2550.0   15063.0      6621.0  Филёвский Парк     24272.0
# 0       ЗАО    2550.0   15063.0      6621.0  Филёвский Парк     24272.0
#
#    totalmen  totalpopul  totalwomen  under18  ...  womenolder  working_ag  \
# 0   26066.0     62378.0     36312.0   8474.0  ...     17651.0     29632.0
# 0   26066.0     62378.0     36312.0   8474.0  ...     17651.0     29632.0
# 0   26066.0     62378.0     36312.0   8474.0  ...     17651.0     29632.0
# 0   26066.0     62378.0     36312.0   8474.0  ...     17651.0     29632.0
# 0   26066.0     62378.0     36312.0   8474.0  ...     17651.0     29632.0
#
#                                             geometry index_right  type  \
# 0  POLYGON ((37.42765 55.74821, 37.42849 55.74875...       24883  node
# 0  POLYGON ((37.42765 55.74821, 37.42849 55.74875...       10439  node
# 0  POLYGON ((37.42765 55.74821, 37.42849 55.74875...        1718  node
# 0  POLYGON ((37.42765 55.74821, 37.42849 55.74875...       32982  node
# 0  POLYGON ((37.42765 55.74821, 37.42849 55.74875...        9550  node
#
#            id        lat        lon  \
# 0  4958136292  55.763153  37.495078
# 0  3068074961  55.764303  37.494623
# 0   971038601  55.742992  37.511425
# 0  6064284540  55.744523  37.512168
# 0  2883190166  55.744799  37.514955
#
#                                                 tags         shop
# 0  {'addr:city': 'Москва', 'addr:housenumber': '2...  supermarket
# 0                            {'shop': 'convenience'}  convenience
# 0                             {'shop': 'car_repair'}   car_repair
# 0                                 {'shop': 'vacant'}       vacant
# 0  {'email': 'info@central-ppk.ru', 'fax': '+7 49...       ticket
#
# [5 rows x 21 columns]

# %%
places_district['shop_count'] = places_district.groupby('name')['id'].transform('nunique')

# %%
district_stats = places_district[['name','geometry', 'shop_count', 'totalpopul']].drop_duplicates('name')#

# %%
district_stats.plot('shop_count', cmap='OrRd', figsize=(12,10), scheme='equals',legend=True);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-81dffbaf5394> in <module>
# ----> 1 district_stats.plot('shop_count', cmap='OrRd', figsize=(12,10), scheme='equals',legend=True);
#
# ~/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     948         kind = kwargs.pop("kind", "geo")
#     949         if kind == "geo":
# --> 950             return plot_dataframe(data, *args, **kwargs)
#     951         if kind in self._pandas_kinds:
#     952             # Access pandas plots
#
# ~/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     746             classification_kwds["k"] = k
#     747
# --> 748         binning = mapclassify.classify(
#     749             np.asarray(values[~nan_idx]), scheme, **classification_kwds
#     750         )
#
# ~/anaconda3/lib/python3.8/site-packages/mapclassify/_classify_API.py in classify(y, scheme, k, pct, pct_sampled, truncate, hinge, multiples, mindiff, initial, bins)
#     128     # check if scheme is a valid scheme
#     129     if scheme not in _classifiers:
# --> 130         raise ValueError("Invalid scheme. Scheme must be in the"
#     131                          " set: %r" % _classifiers.keys())
#     132
#
# ValueError: Invalid scheme. Scheme must be in the set: dict_keys(['boxplot', 'equalinterval', 'fisherjenks', 'fisherjenkssampled', 'headtailbreaks', 'jenkscaspall', 'jenkscaspallforced', 'jenkscaspallsampled', 'maxp', 'maximumbreaks', 'naturalbreaks', 'quantiles', 'percentiles', 'stdmean', 'userdefined'])

# %% [markdown]
# Изменим проекцию на Pseudo-Mercator EPSG:3857

# %%
district_stats = district_stats.to_crs(epsg=3857)

# %%
district_stats.plot('shop_count', cmap='OrRd', figsize=(12,10), scheme='equals', legend=True);
